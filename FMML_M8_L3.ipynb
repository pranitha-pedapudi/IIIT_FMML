# %% [markdown]
# <a href="https://colab.research.google.com/github/pranitha-pedapudi/IIIT_FMML/blob/main/FMML_M8_L3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-23 15:06:23--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  59.7MB/s    in 1.2s
#
# 2025-03-23 15:06:30 (59.7 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 2399   1505.05004v2  We present a novel hybrid algorithm for Bayesi...  stat
# 28048  1705.04528v2  There have been many discriminative learning m...    cs
# 22217  1508.03106v2  Most existing binary classification methods ta...  stat
# 11719  1610.05773v1  Users in social networks whose posts stay at t...  stat
# 24219   1007.0633v1  This paper presents a concept of image pixel f...    cs
# ...             ...                                                ...   ...
# 5086   1803.00781v2  Intrinsically motivated goal exploration algor...    cs
# 29624  1709.09843v1  Exploiting multiple modalities for semantic sc...    cs
# 29660  1710.01073v1  Visual-only speech recognition is dependent up...    cs
# 21776   1309.4859v1  We informally call a stochastic process learna...  stat
# 4658    1207.1406v1  The need to measure sequence similarity arises...    cs
#
#                                                    title  year  \
# 2399   An Experimental Comparison of Hybrid Algorithm...  2015
# 28048  Self-Committee Approach for Image Restoration ...  2017
# 22217  Neyman-Pearson Classification under High-Dimen...  2015
# 11719  RedQueen: An Online Algorithm for Smart Broadc...  2016
# 24219  Classification of fused face images using mult...  2010
# ...                                                  ...   ...
# 5086   Unsupervised Learning of Goal Spaces for Intri...  2018
# 29624   Soft Correspondences in Multimodal Scene Parsing  2017
# 29660     Resolution limits on visual speech recognition  2017
# 21776  Predictive PAC Learning and Process Decomposit...  2013
# 4658   A Conditional Random Field for Discriminativel...  2012
#
#                                                 keywords
# 2399   [algorithm, structure, reconstructs, subroutin...
# 28048  [discriminative, convolutional, restoration, c...
# 22217  [classification, optimization, classification,...
# 11719  [followers, algorithm, stochastic, differentia...
# 24219  [significantly, performance, recognition, reco...
# ...                                                  ...
# 5086   [intrinsically, motivated, exploration, algori...
# 29624  [exploiting, modalities, singlemodality, multi...
# 29660  [recognition, dependent, difficult, expression...
# 21776  [informally, stochastic, learnable, generaliza...
# 4658   [similarity, information, extraction, biologic...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 2399     [algorithm, structure, reconstructs, subroutin...
# 28048    [discriminative, convolutional, restoration, c...
# 22217    [classification, optimization, classification,...
# 11719    [followers, algorithm, stochastic, differentia...
# 24219    [significantly, performance, recognition, reco...
#                                ...
# 10291    [technique, databases, efficiently, estimating...
# 40117    [straightforward, signature, algorithm, embedd...
# 22457    [mortality, developmental, retardation, disabi...
# 11417    [incremental, semiparametric, particular, appr...
# 16927    [strategies, transition, constituent, strategi...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8899 words.
# Out of those 4613 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a3eb2907-9ef1-43ae-a9c1-c7b1cbf7dd78" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a3eb2907-9ef1-43ae-a9c1-c7b1cbf7dd78")) {                    Plotly.newPlot(                        "a3eb2907-9ef1-43ae-a9c1-c7b1cbf7dd78",                        [{"x":["structure","dependence","subroutine","empirical","outperforms","constraint","extensive","currently","available","benchmarks","experiments","algorithm","algorithms","reconstructs","experimental","comparison","incremental","transform","committee","additional","approaches","sometimes","denoising","specifically","discriminative","transformed","functions","convolutional","averaging","evidenced","restoration","different","resolution","conventional","reversible","desirable","simulation","dimensional","constrained","misclassifying","applications","classical","guaranteed","theoretical","inequalities","asymmetric","specified","fundamental","classifiers","counterparts","introduced","construct","demonstrated","prioritized","properties","statistical","classification","diagnosis","priorities","performance","concerned","optimization","advantages","numerical","framework","efficient","differential","broadcasting","stochastic","equations","intensity","consistently","significantly","synthetic","followers","surprisingly","consequence","importantly","expression","occlusions","including","employing","recognition","eigenspace","variations","projected","classified","illumination","identification","individual","benchmark","drawbacks","representation","verification","objective","information","multilayer","perceptron","intractable","frequently","approximation","alternative","complexity","characterize","homogeneity","computationally","quantization","expensive","uncovering","highlight","knowledge","abstractions","descriptors","formulate","harnesses","importance","presented","directions","integrate","diversity","implementation","involving","decisions","alternating","characterizing","communicating","bioinformatics","vocabulary","application","descriptions","underlying","subsequent","regression","convergence","disaggregate","aggregate","gradually","iterative","deviation","procedures","aggregated","iteration","computational","clustering","optimality","aggregating","supervised","approximated","disaggregation","aggregation","advantage","effective","comparisons","bernoulli","recommender","scenarios","correlations","applicability","preference","likelihood","preferential","probability","according","optimizing","illustrate","drastically","obtaining","preferences","acquisition","generalizes","dimensionality","partially","generally","controller","exponential","processes","magnitude","observable","navigation","considered","principal","approximate","compression","complicated","intractability","introduce","techniques","computing","solutions","structured","components","unnecessary","experienced","represent","demonstrate","histories","incorporating","potential","generated","representations"],"y":[324,26,5,149,278,101,157,46,302,95,572,801,570,6,396,156,18,72,6,117,454,21,36,162,104,20,203,361,27,4,16,749,120,103,3,26,72,165,48,1,424,129,24,159,5,9,29,73,113,17,136,74,104,6,219,174,512,45,6,837,15,291,84,82,545,406,24,1,140,22,25,38,233,118,2,33,24,31,43,24,243,42,396,4,68,14,40,41,104,119,203,9,374,39,154,719,13,19,28,27,107,109,227,46,3,80,13,59,2,39,352,10,53,44,2,80,217,48,47,48,136,46,61,33,12,4,9,34,231,42,117,22,95,107,1,15,15,65,12,35,21,44,285,166,20,11,185,16,2,30,96,255,40,2,18,88,28,31,36,54,3,164,103,45,68,16,47,31,51,29,38,47,83,18,51,102,48,24,41,149,38,113,36,32,5,358,388,134,152,93,112,11,6,113,553,4,52,165,175,198],"type":"bar"},{"x":["structure","dependence","subroutine","empirical","outperform ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4613,), (4613, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8241666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Refining</span> <span style=''>Raw</span> <span style=''>Sentence</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Representations</span> <span style=''>for</span> <span style=''>Textual</span> <span style='background-color:rgba(0, 255, 0, 0.8333333333333333);'>Entailment</span> <span style='background-color:rgba(0, 255, 0, 0.6329896907216495);'>Recognition</span> <span style=''>via</span> <span style='background-color:rgba(0, 255, 0, 0.38400000000000006);'>Attention</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>the</span> <span style=''>model</span> <span style=''>used</span> <span style=''>by</span> <span style=''>the</span> <span style=''>team</span> <span style=''>Rivercorners</span> <span style=''>for</span> <span style=''>the</span> <span style=''>2017</span> <span style=''>RepEval</span> <span style=''>shared</span> <span style=''>task</span> <span style=''>First</span> <span style=''>our</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>separately</span> <span style=''>encodes</span> <span style=''>a</span> <span style=''>pair</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.880597014925373);'>sentences</span> <span style=''>into</span> <span style=''>variable</span> <span style=''>length</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>representations</span> <span style=''>by</span> <span style=''>using</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.7272727272727273);'>bidirectional</span> <span style=''>LSTM</span> <span style=''>Later</span> <span style=''>it</span> <span style=''>creates</span> <span style=''>fixed</span> <span style=''>length</span> <span style=''>raw</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>representations</span> <span style=''>by</span> <span style=''>means</span> <span style=''>of</span> <span style=''>simple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>aggregation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>which</span> <span style=''>are</span> <span style=''>then</span> <span style=''>refined</span> <span style=''>using</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.38400000000000006);'>attention</span> <span style='background-color:rgba(0, 255, 0, 0.3289473684210526);'>mechanism</span> <span style=''>Finally</span> <span style=''>it</span> <span style=''>combines</span> <span style=''>the</span> <span style=''>refined</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>representations</span> <span style=''>of</span> <span style=''>both</span> <span style='background-color:rgba(0, 255, 0, 0.880597014925373);'>sentences</span> <span style=''>into</span> <span style=''>a</span> <span style=''>single</span> <span style=''>vector</span> <span style=''>to</span> <span style=''>be</span> <span style=''>used</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>With</span> <span style=''>this</span> <span style=''>model</span> <span style=''>we</span> <span style=''>obtained</span> <span style=''>test</span> <span style='background-color:rgba(0, 255, 0, 0.4857142857142857);'>accuracies</span> <span style=''>of</span> <span style=''>72057</span> <span style=''>and</span> <span style=''>72055</span> <span style=''>in</span> <span style=''>the</span> <span style=''>matched</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>mismatched</span> <span style='background-color:rgba(0, 255, 0, 0.38202247191011235);'>evaluation</span> <span style=''>tracks</span> <span style='background-color:rgba(0, 255, 0, 0.37681159420289856);'>respectively</span> <span style='background-color:rgba(0, 255, 0, 0.30434782608695654);' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Review</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Parameter</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimation</span> <span style=''>in</span> <span style=''>HMRF</span> <br/><br/><span style=''>This</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technical</span> <span style=''>report</span> <span style=''>which</span> <span style=''>explores</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>methodologies</span> <span style=''>on</span> <span style=''>hyper</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>in</span> <span style=''>Markov</span> <span style=''>Random</span> <span style=''>Field</span> <span style=''>and</span> <span style=''>Gaussian</span> <span style=''>Hidden</span> <span style=''>Markov</span> <span style=''>Random</span> <span style=''>Field</span> <span style=''>In</span> <span style=''>first</span> <span style=''>section</span> <span style=''>we</span> <span style=''>briefly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigate</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Metropolis</span> <span style=''>Hastings</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>Next</span> <span style=''>by</span> <span style=''>using</span> <span style=''>MH</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>we</span> <span style=''>simulate</span> <span style=''>the</span> <span style=''>data</span> <span style=''>from</span> <span style=''>Ising</span> <span style=''>model</span> <span style=''>and</span> <span style=''>study</span> <span style=''>on</span> <span style=''>how</span> <span style=''>hyper</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>in</span> <span style=''>Ising</span> <span style=''>model</span> <span style=''>is</span> <span style=''>enabled</span> <span style=''>through</span> <span style=''>MCMC</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>using</span> <span style=''>pseudo</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Following</span> <span style=''>section</span> <span style=''>deals</span> <span style=''>with</span> <span style=''>an</span> <span style=''>issue</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>process</span> <span style=''>of</span> <span style=''>Gaussian</span> <span style=''>Hidden</span> <span style=''>Markov</span> <span style=''>Random</span> <span style=''>Field</span> <span style=''>using</span> <span style=''>MAP</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>and</span> <span style=''>EM</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>and</span> <span style=''>also</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discusses</span> <span style=''>problems</span> <span style=''>found</span> <span style=''>through</span> <span style=''>several</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>following</span> <span style=''>sectio ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Proceedings</span> <span style=''>of</span> <span style=''>the</span> <span style=''>5th</span> <span style=''>Workshop</span> <span style=''>on</span> <span style=''>Machine</span> <span style=''>Learning</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Interpretation</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Neuroimaging</span> <span style=''>(MLINI)</span> <span style=''>at</span> <span style=''>NIPS</span> <span style=''>2015</span> <br/><br/><span style=''>This</span> <span style=''>volume</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collection</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>contributions</span> <span style=''>from</span> <span style=''>the</span> <span style=''>5th</span> <span style=''>Workshop</span> <span style=''>on</span> <span style=''>Machine</span> <span style=''>Learning</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Interpretation</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Neuroimaging</span> <span style=''>(MLINI)</span> <span style=''>at</span> <span style=''>the</span> <span style=''>Neural</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Information</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Processing</span> <span style=''>Systems</span> <span style=''>(NIPS</span> <span style=''>2015)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conference</span> <span style=''>Modern</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multivariate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>methods</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developed</span> <span style=''>in</span> <span style=''>the</span> <span style=''>rapidly</span> <span style=''>growing</span> <span style=''>field</span> <span style=''>of</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>are</span> <span style=''>being</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increasingly</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>various</span> <span style=''>problems</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>neuroimaging</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>cognitive</span> <span style=''>state</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>to</span> <span style=''>clinical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>diagnosis</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prognosis</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Multivariate</span> <span style=''>pattern</span> <span style=''>analysis</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>designed</span> <span style=''>to</span> <span style=''>examine</span> <span style=''>complex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relationships</span> <span style=''>between</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>signals</span> <span style=''>such</span> <span style=''>as</span> <span style=''>brain</span> <span style=''>images</span> <span style=''>and</span> <span style=''>outcomes</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>such</span> <span style=''>as</span> <span style=''>the</span> <span style=''>category</span> <span style=''>of</span> <span style=''>a</span> <span style=''>stimulus</span> <span style=''>a</span> <span style=''>type</span> <span style=''>of</span> <span style=''>a</span> <span style=''>mental</span>  ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10379384395132427)
# 	knowledge (0.12598425196850394)
# 	experimental (0.14173228346456693)
# 	information (0.2573371510379384)
# 	representation (0.13385826771653545)
# 	segmentation (0.07516105941302792)
# 	detection (0.12383679312813171)
# 	different (0.26807444523979956)
# 	convolutional (0.12920544022906227)
# 	recognition (0.14173228346456693)
#
# Some Statistics words are:
# 	stochastic (0.13359920239282153)
# 	algorithm (0.3773678963110668)
# 	variables (0.14057826520438685)
# 	statistical (0.16101694915254236)
# 	estimation (0.16849451645064806)
# 	distribution (0.17846460618145563)
# 	theoretical (0.1719840478564307)
# 	dimensional (0.19292123629112662)
# 	inference (0.21136590229312063)
# 	regression (0.18544366899302095)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d8e2cfbf-4015-4158-83a2-3ff420b0b090" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d8e2cfbf-4015-4158-83a2-3ff420b0b090")) {                    Plotly.newPlot(                        "d8e2cfbf-4015-4158-83a2-3ff420b0b090",                        [{"x":["structure","dependence","subroutine","empirical","outperforms","constraint","extensive","currently","available","benchmarks","experiments","algorithm","algorithms","reconstructs","experimental","comparison","incremental","transform","committee","additional","approaches","sometimes","denoising","specifically","discriminative","transformed","functions","convolutional","averaging","evidenced","restoration","different","resolution","conventional","reversible","desirable","simulation","dimensional","constrained","misclassifying","applications","classical","guaranteed","theoretical","inequalities","asymmetric","specified","fundamental","classifiers","counterparts","introduced","construct","demonstrated","prioritized","properties","statistical","classification","diagnosis","priorities","performance","concerned","optimization","advantages","numerical","framework","efficient","differential","broadcasting","stochastic","equations","intensity","consistently","significantly","synthetic","followers","surprisingly","consequence","importantly","expression","occlusions","including","employing","recognition","eigenspace","variations","projected","classified","illumination","identification","individual","benchmark","drawbacks","representation","verification","objective","information","multilayer","perceptron","intractable","frequently","approximation","alternative","complexity","characterize","homogeneity","computationally","quantization","expensive","uncovering","highlight","knowledge","abstractions","descriptors","formulate","harnesses","importance","presented","directions","integrate","diversity","implementation","involving","decisions","alternating","characterizing","communicating","bioinformatics","vocabulary","application","descriptions","underlying","subsequent","regression","convergence","disaggregate","aggregate","gradually","iterative","deviation","procedures","aggregated","iteration","computational","clustering","optimality","aggregating","supervised","approximated","disaggregation","aggregation","advantage","effective","comparisons","bernoulli","recommender","scenarios","correlations","applicability","preference","likelihood","preferential","probability","according","optimizing","illustrate","drastically","obtaining","preferences","acquisition","generalizes","dimensionality","partially","generally","controller","exponential","processes","magnitude","observable","navigation","considered","principal","approximate","compression","complicated","intractability","introduce","techniques","computing","solutions","structured","components","unnecessary","experienced","represent","demonstrate","histories","incorporating","potential","generated","representations","probabilistic","recommendations","predictive","continuous","threefold","awareness","represents","alleviate","filtering","targeting","downstream","ecosystem","respectively","flexibility","heuristic","independent","statistically","adjustable","generalization","construction","improvement","parameter","relations","simplicity","criterion","significant","extending","predictors","comparing","selection","contrasting","penalties","nonconvex","variables","efficiently","penalized","selecting","attractive","developed","distributions","exploration","particular","facilitates","limitations","variational","distribution","dependent","simultaneously","interpretable","calculate","inference","interactions","biomedical","parameters","exploitatio ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	ergodicity
# 	minimizer
# 	robustification
# 	admitting
# 	contingency
# 	dendrogram
# 	unbiasedness
# 	equitable
# 	equitability
# 	trilinear
# 	exogenous
# 	unobservable
# 	assimilation
# 	assimilating
# 	penalizing
# 	reconcile
# 	subdifferential
# 	tibshirani
# 	gaussianity
# 	dimensionalities
# Some words which never appear in Statistics papers:
# 	occlusions
# 	abstractions
# 	navigation
# 	threefold
# 	ecosystem
# 	vertebral
# 	vertebrae
# 	osteoporosis
# 	subnetwork
# 	abbreviations
# 	punctuation
# 	standardised
# 	denoisers
# 	attentional
# 	allocated
# 	humanoids
# 	coordination
# 	synergetic
# 	abstraction
# 	commonsense

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0719134949159833e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7841666666666667
